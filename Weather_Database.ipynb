# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 748

# %%
import requests

from config import weather_api_key_2

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key_2
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dfe666694606421dd1d8b64624afbb34

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1
for i, city in enumerate(cities):
 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    record_count += 1
    try:
        
        city_weather = requests.get(city_url).json()
#         print(city_weather)
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']

        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | san juan
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | hervey bay
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | waddan
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | ylojarvi
# Processing Record 23 of Set 1 | general salgado
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | khudumelapye
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | ambon
# Processing Record 30 of Set 1 | ixtapa
# Processing Record 31 of Set 1 | zarubino
# Processing Record 32 of Set 1 | la libertad
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | limoges
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | den helder
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | morehead
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | pak phanang
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | dombarovskiy
# Processing Record 48 of Set 1 | zhuhai
# Processing Record 49 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | santa isabel do rio negro
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | porto uniao
# Processing Record 4 of Set 2 | bagdarin
# Processing Record 5 of Set 2 | srikakulam
# Processing Record 6 of Set 2 | wenling
# Processing Record 7 of Set 2 | pangody
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | itarema
# Processing Record 10 of Set 2 | buala
# Processing Record 11 of Set 2 | fort nelson
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | yamada
# Processing Record 15 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 16 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | zaysan
# Processing Record 20 of Set 2 | sasaram
# Processing Record 21 of Set 2 | honiara
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | kieta
# Processing Record 24 of Set 2 | bonavista
# Processing Record 25 of Set 2 | shingu
# Processing Record 26 of Set 2 | churapcha
# Processing Record 27 of Set 2 | harper
# Processing Record 28 of Set 2 | mount gambier
# Processing Record 29 of Set 2 | guiglo
# Processing Record 30 of Set 2 | ostersund
# Processing Record 31 of Set 2 | montijo
# Processing Record 32 of Set 2 | bria
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | cap-aux-meules
# Processing Record 38 of Set 2 | yagodnoye
# Processing Record 39 of Set 2 | lakatoro
# Processing Record 40 of Set 2 | benjamin hill
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | el dovio
# Processing Record 43 of Set 2 | nogliki
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | antofagasta
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | henties bay
# Processing Record 49 of Set 2 | porto santo
# Processing Record 50 of Set 2 | stephenville
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | tateyama
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | eyrarbakki
# Processing Record 12 of Set 3 | khorramshahr
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | dunedin
# Processing Record 18 of Set 3 | udachnyy
# Processing Record 19 of Set 3 | pemba
# Processing Record 20 of Set 3 | maceio
# Processing Record 21 of Set 3 | nova olimpia
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | korla
# Processing Record 25 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 3 | cachira
# Processing Record 27 of Set 3 | samarai
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | asau
# Processing Record 30 of Set 3 | praia da vitoria
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | iwanai
# Processing Record 33 of Set 3 | brigantine
# Processing Record 34 of Set 3 | kangaatsiaq
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | lamont
# Processing Record 38 of Set 3 | totskoye
# Processing Record 39 of Set 3 | havelock
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | huanren
# Processing Record 42 of Set 3 | juneau
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | pastos bons
# Processing Record 50 of Set 3 | mangaratiba
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | erenhot
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | nome
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | yairipok
# Processing Record 8 of Set 4 | chumikan
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | machacamarca
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | port moresby
# Processing Record 14 of Set 4 | mvuma
# Processing Record 15 of Set 4 | cayenne
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | uruzgan
# Processing Record 18 of Set 4 | abu dhabi
# Processing Record 19 of Set 4 | sidi ali
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | westport
# Processing Record 22 of Set 4 | esso
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | chapais
# Processing Record 26 of Set 4 | saint-georges
# Processing Record 27 of Set 4 | pundaguitan
# Processing Record 28 of Set 4 | pimentel
# Processing Record 29 of Set 4 | san luis
# Processing Record 30 of Set 4 | olinda
# Processing Record 31 of Set 4 | punta arenas
# Processing Record 32 of Set 4 | eureka
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | bannu
# Processing Record 35 of Set 4 | hofn
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | nyrob
# Processing Record 38 of Set 4 | olafsvik
# Processing Record 39 of Set 4 | solnechnyy
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | luorong
# Processing Record 42 of Set 4 | vila franca do campo
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | metro
# Processing Record 45 of Set 4 | tura
# Processing Record 46 of Set 4 | dongsheng
# Processing Record 47 of Set 4 | camopi
# Processing Record 48 of Set 4 | kagoro
# Processing Record 49 of Set 4 | usoke
# Processing Record 50 of Set 4 | manta
# Processing Record 1 of Set 5 | saint pete beach
# Processing Record 2 of Set 5 | santa maria
# Processing Record 3 of Set 5 | san policarpo
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | qaqortoq
# Processing Record 6 of Set 5 | haimen
# Processing Record 7 of Set 5 | sile
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | noumea
# Processing Record 11 of Set 5 | griffith
# Processing Record 12 of Set 5 | warman
# Processing Record 13 of Set 5 | mandalgovi
# Processing Record 14 of Set 5 | prado
# Processing Record 15 of Set 5 | letnik
# Processing Record 16 of Set 5 | sao joao da barra
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 5 | broken hill
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | pilar
# Processing Record 22 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 5 | mbandaka
# Processing Record 24 of Set 5 | bouna
# Processing Record 25 of Set 5 | iwata
# Processing Record 26 of Set 5 | egvekinot
# Processing Record 27 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 5 | camana
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | wajid
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | ballina
# Processing Record 33 of Set 5 | chestermere
# Processing Record 34 of Set 5 | saint george
# Processing Record 35 of Set 5 | ugra
# Processing Record 36 of Set 5 | prieska
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | tupik
# Processing Record 39 of Set 5 | izhma
# Processing Record 40 of Set 5 | richards bay
# Processing Record 41 of Set 5 | kihei
# Processing Record 42 of Set 5 | tessalit
# Processing Record 43 of Set 5 | warrington
# Processing Record 44 of Set 5 | gamba
# Processing Record 45 of Set 5 | vestmanna
# Processing Record 46 of Set 5 | iracoubo
# Processing Record 47 of Set 5 | sivas
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | tual
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | ushumun
# Processing Record 5 of Set 6 | bathsheba
# Processing Record 6 of Set 6 | salinopolis
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | sambava
# Processing Record 9 of Set 6 | chilca
# Processing Record 10 of Set 6 | camocim
# Processing Record 11 of Set 6 | tecoanapa
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | pathein
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | loubomo
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | palaiokhora
# City not found. Skipping...
# Processing Record 19 of Set 6 | pringsewu
# Processing Record 20 of Set 6 | esperance
# Processing Record 21 of Set 6 | naze
# Processing Record 22 of Set 6 | orlik
# Processing Record 23 of Set 6 | lock haven
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | sulangan
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | hamilton
# Processing Record 29 of Set 6 | bredasdorp
# Processing Record 30 of Set 6 | coolum beach
# Processing Record 31 of Set 6 | mount isa
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | srednekolymsk
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | yenagoa
# Processing Record 36 of Set 6 | khanu woralaksaburi
# Processing Record 37 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | zaqatala
# Processing Record 40 of Set 6 | komsomolskiy
# Processing Record 41 of Set 6 | berbera
# Processing Record 42 of Set 6 | saint-paul
# Processing Record 43 of Set 6 | marsh harbour
# Processing Record 44 of Set 6 | nicoya
# Processing Record 45 of Set 6 | rocha
# Processing Record 46 of Set 6 | alyangula
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | hambantota
# Processing Record 50 of Set 6 | ahuimanu
# Processing Record 1 of Set 7 | isangel
# Processing Record 2 of Set 7 | conde
# Processing Record 3 of Set 7 | tevaitoa
# Processing Record 4 of Set 7 | san ramon
# Processing Record 5 of Set 7 | makakilo city
# Processing Record 6 of Set 7 | pozo colorado
# Processing Record 7 of Set 7 | hunucma
# Processing Record 8 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 9 of Set 7 | comodoro rivadavia
# Processing Record 10 of Set 7 | qurunbaliyah
# City not found. Skipping...
# Processing Record 11 of Set 7 | ponca city
# Processing Record 12 of Set 7 | chihuahua
# Processing Record 13 of Set 7 | gornopravdinsk
# Processing Record 14 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 7 | christchurch
# Processing Record 16 of Set 7 | north bend
# Processing Record 17 of Set 7 | sola
# Processing Record 18 of Set 7 | okha
# Processing Record 19 of Set 7 | lagdo
# Processing Record 20 of Set 7 | ferkessedougou
# Processing Record 21 of Set 7 | rockland
# Processing Record 22 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 7 | duluth
# Processing Record 24 of Set 7 | tashigang
# Processing Record 25 of Set 7 | grand-santi
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 7 | tevriz
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | lima
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | bandarban
# Processing Record 33 of Set 7 | mbigou
# Processing Record 34 of Set 7 | aswan
# Processing Record 35 of Set 7 | todos santos
# Processing Record 36 of Set 7 | villa rica
# Processing Record 37 of Set 7 | crestview
# Processing Record 38 of Set 7 | luziania
# Processing Record 39 of Set 7 | kloulklubed
# Processing Record 40 of Set 7 | mae ramat
# Processing Record 41 of Set 7 | guerrero negro
# Processing Record 42 of Set 7 | kandrian
# Processing Record 43 of Set 7 | svetlyy
# Processing Record 44 of Set 7 | barranca
# Processing Record 45 of Set 7 | kropotkin
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | tomohon
# Processing Record 48 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 7 | lucea
# Processing Record 1 of Set 8 | inverell
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | pierre
# Processing Record 4 of Set 8 | gao
# Processing Record 5 of Set 8 | tsuruga
# Processing Record 6 of Set 8 | kastamonu
# Processing Record 7 of Set 8 | fulitun
# City not found. Skipping...
# Processing Record 8 of Set 8 | kultayevo
# Processing Record 9 of Set 8 | aklavik
# Processing Record 10 of Set 8 | bambanglipuro
# Processing Record 11 of Set 8 | chirilagua
# Processing Record 12 of Set 8 | conceicao da barra
# Processing Record 13 of Set 8 | labuhan
# Processing Record 14 of Set 8 | svetlogorsk
# Processing Record 15 of Set 8 | changji
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | coihaique
# Processing Record 18 of Set 8 | tuy hoa
# Processing Record 19 of Set 8 | tandalti
# Processing Record 20 of Set 8 | halifax
# Processing Record 21 of Set 8 | necochea
# Processing Record 22 of Set 8 | abramovka
# Processing Record 23 of Set 8 | karaj
# Processing Record 24 of Set 8 | ransang
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | biltine
# Processing Record 27 of Set 8 | kawalu
# Processing Record 28 of Set 8 | mwinilunga
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | morbach
# Processing Record 31 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 8 | blagodatnoye
# Processing Record 34 of Set 8 | sosnovka
# Processing Record 35 of Set 8 | usvyaty
# Processing Record 36 of Set 8 | swinoujscie
# Processing Record 37 of Set 8 | snasa
# Processing Record 38 of Set 8 | faya
# Processing Record 39 of Set 8 | razole
# Processing Record 40 of Set 8 | perth
# Processing Record 41 of Set 8 | moose factory
# Processing Record 42 of Set 8 | pietersburg
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | leningradskiy
# Processing Record 45 of Set 8 | punta alta
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | lagoa
# Processing Record 48 of Set 8 | oranjemund
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 50 of Set 8 | amuntai
# Processing Record 1 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 9 | san cristobal
# Processing Record 3 of Set 9 | benguela
# Processing Record 4 of Set 9 | portree
# Processing Record 5 of Set 9 | byron bay
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | poya
# Processing Record 8 of Set 9 | lompoc
# Processing Record 9 of Set 9 | batticaloa
# Processing Record 10 of Set 9 | baykit
# Processing Record 11 of Set 9 | shaoyang
# Processing Record 12 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 9 | west wendover
# Processing Record 14 of Set 9 | ust-maya
# Processing Record 15 of Set 9 | usinsk
# Processing Record 16 of Set 9 | heyang
# Processing Record 17 of Set 9 | san lawrenz
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 9 | okmulgee
# Processing Record 21 of Set 9 | nanortalik
# Processing Record 22 of Set 9 | jalu
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | marathon
# Processing Record 25 of Set 9 | pangai
# Processing Record 26 of Set 9 | houma
# Processing Record 27 of Set 9 | sinnamary
# Processing Record 28 of Set 9 | gushikawa
# Processing Record 29 of Set 9 | muzhi
# Processing Record 30 of Set 9 | saint-pierre
# Processing Record 31 of Set 9 | balabac
# Processing Record 32 of Set 9 | carmen
# Processing Record 33 of Set 9 | muhos
# Processing Record 34 of Set 9 | dalian
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | mehran
# Processing Record 39 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 9 | grand falls
# Processing Record 41 of Set 9 | basco
# Processing Record 42 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 43 of Set 9 | meulaboh
# Processing Record 44 of Set 9 | narsaq
# Processing Record 45 of Set 9 | gorontalo
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | bemidji
# Processing Record 48 of Set 9 | powell
# Processing Record 49 of Set 9 | ouargaye
# Processing Record 50 of Set 9 | priargunsk
# Processing Record 1 of Set 10 | celina
# Processing Record 2 of Set 10 | cariati
# Processing Record 3 of Set 10 | kyshtovka
# Processing Record 4 of Set 10 | havoysund
# Processing Record 5 of Set 10 | port hardy
# Processing Record 6 of Set 10 | pyinmana
# Processing Record 7 of Set 10 | kashi
# Processing Record 8 of Set 10 | sinegorye
# Processing Record 9 of Set 10 | taltal
# Processing Record 10 of Set 10 | tapejara
# Processing Record 11 of Set 10 | na klang
# Processing Record 12 of Set 10 | bakhtiyarpur
# Processing Record 13 of Set 10 | alto vera
# City not found. Skipping...
# Processing Record 14 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 10 | kirakira
# Processing Record 16 of Set 10 | ust-uda
# Processing Record 17 of Set 10 | yinchuan
# Processing Record 18 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 10 | lakes entrance
# Processing Record 20 of Set 10 | florianopolis
# Processing Record 21 of Set 10 | manokwari
# Processing Record 22 of Set 10 | cidreira
# Processing Record 23 of Set 10 | bereda
# Processing Record 24 of Set 10 | muroto
# Processing Record 25 of Set 10 | piripiri
# Processing Record 26 of Set 10 | arman
# Processing Record 27 of Set 10 | vestmannaeyjar
# Processing Record 28 of Set 10 | lardos
# Processing Record 29 of Set 10 | artsyz
# Processing Record 30 of Set 10 | huaraz
# Processing Record 31 of Set 10 | preston
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | evensk
# Processing Record 34 of Set 10 | pakokku
# Processing Record 35 of Set 10 | sioux lookout
# Processing Record 36 of Set 10 | kurilsk
# Processing Record 37 of Set 10 | sinjai
# Processing Record 38 of Set 10 | ararat
# Processing Record 39 of Set 10 | yining
# Processing Record 40 of Set 10 | bull savanna
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | salvador
# Processing Record 43 of Set 10 | unai
# Processing Record 44 of Set 10 | burnie
# Processing Record 45 of Set 10 | russell
# Processing Record 46 of Set 10 | tonj
# Processing Record 47 of Set 10 | loukhi
# Processing Record 48 of Set 10 | gilbues
# Processing Record 49 of Set 10 | chuy
# Processing Record 50 of Set 10 | mehadica
# Processing Record 1 of Set 11 | dakar
# Processing Record 2 of Set 11 | adrar
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | mapiripan
# Processing Record 5 of Set 11 | khandyga
# Processing Record 6 of Set 11 | la ronge
# Processing Record 7 of Set 11 | huarmey
# Processing Record 8 of Set 11 | carlagan
# Processing Record 9 of Set 11 | kjopsvik
# Processing Record 10 of Set 11 | quchan
# Processing Record 11 of Set 11 | lazaro cardenas
# Processing Record 12 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 11 | skjervoy
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | buchanan
# Processing Record 16 of Set 11 | hualmay
# Processing Record 17 of Set 11 | kortkeros
# Processing Record 18 of Set 11 | healdsburg
# Processing Record 19 of Set 11 | vila do maio
# Processing Record 20 of Set 11 | muzhappilangad
# City not found. Skipping...
# Processing Record 21 of Set 11 | daru
# Processing Record 22 of Set 11 | ardakan
# Processing Record 23 of Set 11 | raga
# Processing Record 24 of Set 11 | kirkwall
# Processing Record 25 of Set 11 | belmonte
# Processing Record 26 of Set 11 | katsuura
# Processing Record 27 of Set 11 | casablanca
# Processing Record 28 of Set 11 | cherskiy
# Processing Record 29 of Set 11 | yarmouth
# Processing Record 30 of Set 11 | nichlaul
# Processing Record 31 of Set 11 | harnosand
# Processing Record 32 of Set 11 | viedma
# Processing Record 33 of Set 11 | zabol
# Processing Record 34 of Set 11 | chino valley
# Processing Record 35 of Set 11 | gillette
# Processing Record 36 of Set 11 | tukrah
# Processing Record 37 of Set 11 | north las vegas
# Processing Record 38 of Set 11 | conceicao do araguaia
# Processing Record 39 of Set 11 | mugur-aksy
# Processing Record 40 of Set 11 | san rafael del sur
# Processing Record 41 of Set 11 | zapolyarnyy
# Processing Record 42 of Set 11 | uspantan
# Processing Record 43 of Set 11 | bronnoysund
# Processing Record 44 of Set 11 | uchiza
# Processing Record 45 of Set 11 | nouakchott
# Processing Record 46 of Set 11 | bahia blanca
# Processing Record 47 of Set 11 | tonantins
# Processing Record 48 of Set 11 | sembe
# Processing Record 49 of Set 11 | otelu rosu
# Processing Record 50 of Set 11 | sawakin
# Processing Record 1 of Set 12 | caravelas
# Processing Record 2 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 3 of Set 12 | zarate
# Processing Record 4 of Set 12 | moron
# Processing Record 5 of Set 12 | novyy urgal
# Processing Record 6 of Set 12 | shimoda
# Processing Record 7 of Set 12 | cuamba
# Processing Record 8 of Set 12 | yuma
# Processing Record 9 of Set 12 | padang
# Processing Record 10 of Set 12 | vanavara
# Processing Record 11 of Set 12 | cap malheureux
# Processing Record 12 of Set 12 | tarauaca
# Processing Record 13 of Set 12 | banda aceh
# Processing Record 14 of Set 12 | kuytun
# Processing Record 15 of Set 12 | ekibastuz
# Processing Record 16 of Set 12 | druzhba
# Processing Record 17 of Set 12 | pita
# Processing Record 18 of Set 12 | salmas
# Processing Record 19 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 12 | neryungri
# Processing Record 21 of Set 12 | coquimbo
# Processing Record 22 of Set 12 | novooleksiyivka
# Processing Record 23 of Set 12 | zeya
# Processing Record 24 of Set 12 | wheatley
# Processing Record 25 of Set 12 | mwense
# Processing Record 26 of Set 12 | purna
# Processing Record 27 of Set 12 | zhigalovo
# Processing Record 28 of Set 12 | orange cove
# Processing Record 29 of Set 12 | acajutla
# Processing Record 30 of Set 12 | acolla
# Processing Record 31 of Set 12 | sibolga
# Processing Record 32 of Set 12 | ilulissat
# Processing Record 33 of Set 12 | moron de la frontera
# Processing Record 34 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | staroaleyskoye
# Processing Record 37 of Set 12 | leshukonskoye
# Processing Record 38 of Set 12 | nuevo progreso
# Processing Record 39 of Set 12 | novospasskoye
# Processing Record 40 of Set 12 | kwinana
# Processing Record 41 of Set 12 | fria
# Processing Record 42 of Set 12 | tahe
# Processing Record 43 of Set 12 | ulladulla
# Processing Record 44 of Set 12 | charlestown
# Processing Record 45 of Set 12 | severodvinsk
# Processing Record 46 of Set 12 | san clemente
# Processing Record 47 of Set 12 | kinablangan
# Processing Record 48 of Set 12 | sosenskiy
# Processing Record 49 of Set 12 | formosa
# Processing Record 50 of Set 12 | talaya
# Processing Record 1 of Set 13 | lingao
# Processing Record 2 of Set 13 | beringovskiy
# Processing Record 3 of Set 13 | grand baie
# Processing Record 4 of Set 13 | mezen
# Processing Record 5 of Set 13 | luganville
# Processing Record 6 of Set 13 | snyder
# Processing Record 7 of Set 13 | nishihara
# Processing Record 8 of Set 13 | jiaohe
# Processing Record 9 of Set 13 | xining
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | cortland
# Processing Record 12 of Set 13 | mantua
# Processing Record 13 of Set 13 | saint-augustin
# Processing Record 14 of Set 13 | anloga
# Processing Record 15 of Set 13 | mehamn
# Processing Record 16 of Set 13 | isla vista
# Processing Record 17 of Set 13 | shestakovo
# Processing Record 18 of Set 13 | vardo
# Processing Record 19 of Set 13 | turayf
# Processing Record 20 of Set 13 | akdepe
# Processing Record 21 of Set 13 | glenwood springs
# Processing Record 22 of Set 13 | angouleme
# Processing Record 23 of Set 13 | namtsy
# Processing Record 24 of Set 13 | macapa
# Processing Record 25 of Set 13 | grajau
# Processing Record 26 of Set 13 | arvika
# Processing Record 27 of Set 13 | sakakah
# Processing Record 28 of Set 13 | alekseyevka
# Processing Record 29 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 13 | rio verde de mato grosso
# Processing Record 31 of Set 13 | raipur
# Processing Record 32 of Set 13 | manutuke
# Processing Record 33 of Set 13 | challakere
# Processing Record 34 of Set 13 | liling
# Processing Record 35 of Set 13 | ponta delgada
# Processing Record 36 of Set 13 | imbituba
# Processing Record 37 of Set 13 | ola
# Processing Record 38 of Set 13 | big spring
# Processing Record 39 of Set 13 | acapulco
# Processing Record 40 of Set 13 | lagos
# Processing Record 41 of Set 13 | balkhash
# Processing Record 42 of Set 13 | bandarbeyla
# Processing Record 43 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 13 | sept-iles
# Processing Record 45 of Set 13 | le vauclin
# Processing Record 46 of Set 13 | fort walton beach
# Processing Record 47 of Set 13 | cody
# Processing Record 48 of Set 13 | potchefstroom
# Processing Record 49 of Set 13 | palmer
# Processing Record 50 of Set 13 | kindu
# Processing Record 1 of Set 14 | ankang
# Processing Record 2 of Set 14 | najran
# Processing Record 3 of Set 14 | puerto penasco
# Processing Record 4 of Set 14 | atar
# Processing Record 5 of Set 14 | kungurtug
# Processing Record 6 of Set 14 | cassilandia
# Processing Record 7 of Set 14 | sobolevo
# Processing Record 8 of Set 14 | saint-andre-les-vergers
# Processing Record 9 of Set 14 | kutum
# Processing Record 10 of Set 14 | hovd
# Processing Record 11 of Set 14 | rio grande
# Processing Record 12 of Set 14 | natal
# Processing Record 13 of Set 14 | paragominas
# Processing Record 14 of Set 14 | salinas
# Processing Record 15 of Set 14 | prince rupert
# Processing Record 16 of Set 14 | sumkino
# Processing Record 17 of Set 14 | soloneshnoye
# Processing Record 18 of Set 14 | chernyshevskiy
# Processing Record 19 of Set 14 | naron
# Processing Record 20 of Set 14 | roma
# Processing Record 21 of Set 14 | san rafael
# Processing Record 22 of Set 14 | roebourne
# Processing Record 23 of Set 14 | jacareacanga
# Processing Record 24 of Set 14 | pacsa
# Processing Record 25 of Set 14 | tome
# Processing Record 26 of Set 14 | panjab
# Processing Record 27 of Set 14 | praia
# Processing Record 28 of Set 14 | high level
# Processing Record 29 of Set 14 | yongan
# Processing Record 30 of Set 14 | ayorou
# Processing Record 31 of Set 14 | rochegda
# Processing Record 32 of Set 14 | ler
# Processing Record 33 of Set 14 | tiznit
# Processing Record 34 of Set 14 | araioses
# Processing Record 35 of Set 14 | veraval
# Processing Record 36 of Set 14 | sao paulo de olivenca
# Processing Record 37 of Set 14 | chiang rai
# Processing Record 38 of Set 14 | grindavik
# Processing Record 39 of Set 14 | neckargemund
# Processing Record 40 of Set 14 | sao gabriel da cachoeira
# Processing Record 41 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 42 of Set 14 | alice springs
# Processing Record 43 of Set 14 | general roca
# Processing Record 44 of Set 14 | tsiroanomandidy
# Processing Record 45 of Set 14 | whitianga
# Processing Record 46 of Set 14 | barstow
# Processing Record 47 of Set 14 | bafq
# Processing Record 48 of Set 14 | saint-joseph
# Processing Record 49 of Set 14 | nyaunglebin
# Processing Record 50 of Set 14 | soyo
# Processing Record 1 of Set 15 | manhattan
# Processing Record 2 of Set 15 | axim
# Processing Record 3 of Set 15 | simplicio mendes
# Processing Record 4 of Set 15 | nuuk
# Processing Record 5 of Set 15 | bud
# Processing Record 6 of Set 15 | saint-leu
# Processing Record 7 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 15 | taraza
# Processing Record 9 of Set 15 | wageningen
# Processing Record 10 of Set 15 | mus
# Processing Record 11 of Set 15 | kalmunai
# Processing Record 12 of Set 15 | port augusta
# Processing Record 13 of Set 15 | teahupoo
# Processing Record 14 of Set 15 | port-gentil
# Processing Record 15 of Set 15 | raudeberg
# Processing Record 16 of Set 15 | pandan
# Processing Record 17 of Set 15 | jiangyou
# Processing Record 18 of Set 15 | krasnoselkup
# Processing Record 19 of Set 15 | arshan
# Processing Record 20 of Set 15 | filimonovo
# Processing Record 21 of Set 15 | dryden
# Processing Record 22 of Set 15 | kamaishi
# Processing Record 23 of Set 15 | tubmanburg
# Processing Record 24 of Set 15 | batagay-alyta
# Processing Record 25 of Set 15 | sabang
# Processing Record 26 of Set 15 | ngunguru
# Processing Record 27 of Set 15 | san quintin
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | lagarto
# Processing Record 30 of Set 15 | west bay
# Processing Record 31 of Set 15 | elbrus
# Processing Record 32 of Set 15 | gladstone
# Processing Record 33 of Set 15 | tera
# Processing Record 34 of Set 15 | ahvaz
# Processing Record 35 of Set 15 | murgab
# Processing Record 36 of Set 15 | sesheke
# Processing Record 37 of Set 15 | darasun
# Processing Record 38 of Set 15 | gizo
# Processing Record 39 of Set 15 | harrai
# Processing Record 40 of Set 15 | huambo
# Processing Record 41 of Set 15 | almaznyy
# Processing Record 42 of Set 15 | poplar bluff
# Processing Record 43 of Set 15 | deqing
# Processing Record 44 of Set 15 | lewiston
# Processing Record 45 of Set 15 | durban
# Processing Record 46 of Set 15 | varna
# Processing Record 47 of Set 15 | tamandare
# Processing Record 48 of Set 15 | mopti
# -----------------------------
# Data Retrieval Complete

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     San Juan      AR -31.5375  -68.5364     91.36        31           0
# 1        Vaini      TO -21.2000 -175.2000     84.20        79          20
# 2   Hervey Bay      AU -25.2986  152.8535     78.01        77           4
# 3      Qaanaaq      GL  77.4840  -69.3632      7.41        76          74
# 4       Waddan      LY  29.1614   16.1390     49.42        60           0
# 5  Tuktoyaktuk      CA  69.4541 -133.0374     -7.60        77          90
# 6       Laguna      US  38.4210 -121.4238     51.80        87          90
# 7       Kodiak      US  57.7900 -152.4072     37.40        93          90
# 8      Mataura      NZ -46.1927  168.8643     73.00        64          47
# 9      Rikitea      PF -23.1203 -134.9692     77.58        72          77
#
#    Wind Speed Current Description
# 0       19.22           clear sky
# 1        8.05          few clouds
# 2        3.00           clear sky
# 3        4.99       broken clouds
# 4        0.87           clear sky
# 5        8.05     overcast clouds
# 6        4.61                mist
# 7       32.21          light rain
# 8        3.00    scattered clouds
# 9       10.13       broken clouds

# %%
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
