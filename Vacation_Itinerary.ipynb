# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Weather_database/WeatherPy_vacation.csv")
vacation_df.head(20)
# Out:
#     City ID                       City Country  Max Temp Current Description  \
# 0         1                      Vaini      TO     84.20          few clouds
# 1         2                 Hervey Bay      AU     78.01           clear sky
# 2         9                    Rikitea      PF     77.58       broken clouds
# 3        10                      Kapaa      US     77.00          light rain
# 4        14                  Carnarvon      AU     77.00           clear sky
# 5        17                 Butaritari      KI     81.32    scattered clouds
# 6        19            General Salgado      BR     75.90     overcast clouds
# 7        21               Puerto Ayora      EC     80.60       broken clouds
# 8        24                      Ambon      ID     79.00    scattered clouds
# 9        27                La Libertad      EC     84.20           clear sky
# 10       36                Pak Phanang      TH     77.43     overcast clouds
# 11       39                East London      ZA     75.72       broken clouds
# 12       45  Santa Isabel Do Rio Negro      BR     82.00     overcast clouds
# 13       46                    Kavieng      PG     83.53     overcast clouds
# 14       53                    Itarema      BR     79.30    scattered clouds
# 15       54                      Buala      SB     84.24       broken clouds
# 16       63                    Honiara      SB     84.49     overcast clouds
# 17       69                     Harper      LR     78.55          light rain
# 18       71                     Guiglo      CI     76.32    scattered clouds
# 19       76             Saint-Philippe      RE     78.80       broken clouds
#
#         Lat       Lng                              Hotel Name
# 0  -21.2000 -175.2000                     Keleti Beach Resort
# 1  -25.2986  152.8535                       Shelly Bay Resort
# 2  -23.1203 -134.9692                          Pension Maro'i
# 3   22.0752 -159.3190  Sheraton Kauai Resort at Coconut Beach
# 4  -24.8667  113.6333                   Hospitality Carnarvon
# 5    3.0707  172.7902                      Isles Sunset Lodge
# 6  -20.6483  -50.3606                              TUTU HOTEL
# 7   -0.7393  -90.3518                      Castillo Galapagos
# 8   -3.6954  128.1814                    Swiss-Belhotel Ambon
# 9   -2.2333  -80.9000             Playa Canela Hotel Boutique
# 10   8.3511  100.2020                    Green Park Inn Hotel
# 11 -33.0153   27.9116                                 Tu Casa
# 12  -0.4139  -65.0192                               Hotel GSA
# 13  -2.5744  150.7967                     Nusa Island Retreat
# 14  -2.9248  -39.9167      Sea Lounge! Bar, Club & Restaurant
# 15  -8.1450  159.5921                    Maringe Lagoon Lodge
# 16  -9.4333  159.9500                     Heritage Park Hotel
# 17   4.3750   -7.7169                             Screensaver
# 18   6.5456   -7.4966                          Hotel GBAOLY 2
# 19 -21.3585   55.7679            Chambres d'hôte "La Trinité"

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]==("Salinas")]
vacation_end = vacation_df.loc[vacation_df["City"]==("Salinas")]
vacation_stop1 = vacation_df.loc[vacation_df["City"]==("Lompoc")]
vacation_stop2 = vacation_df.loc[vacation_df["City"]==("Isla Vista")]
vacation_stop3 = vacation_df.loc[vacation_df["City"]==("San Clemente")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0]
end = vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0]
stop1 = vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]
stop2 = vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0]
stop3 = vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
waypoints = [stop1, stop2, stop3]
directions = gmaps.directions_layer(start, end, waypoints=waypoints,travel_mode='DRIVING')
fig = gmaps.figure()
fig.add_layer(directions)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1,vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City ID          City Country  Max Temp Current Description      Lat  \
# 0      614       Salinas      US      75.2           clear sky  36.6777
# 1      373        Lompoc      US      80.6           clear sky  34.6391
# 2      568    Isla Vista      US      82.0           clear sky  34.4133
# 3      548  San Clemente      US      81.0           clear sky  33.4270
#
#         Lng                         Hotel Name
# 0 -121.6555     Good Nite Inn Salinas Monterey
# 1 -120.4579         Holiday Inn Express Lompoc
# 2 -119.8610  Best Western Plus South Coast Inn
# 3 -117.6120                     Casablanca Inn

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
